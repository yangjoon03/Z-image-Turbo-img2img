# %% [markdown]
# ### 단일 처리 픽셀화

# %%
import torch
from diffusers import ZImageImg2ImgPipeline # Img2Img 전용 파이프라인으로 변경
from diffusers.utils import load_image

# 1. 파이프라인 로드 (Img2Img용)
pipe = ZImageImg2ImgPipeline.from_pretrained(
    "Tongyi-MAI/Z-Image-Turbo",
    torch_dtype=torch.bfloat16,
    low_cpu_mem_usage=True,
)
pipe.to("cuda")

# 2. 원본 이미지 불러오기 (경로를 본인의 파일명으로 수정하세요)
init_image = load_image("21.png").convert("RGB")

# 3. 애니메이션 스타일 프롬프트 설정
prompt = "anime style, high-quality, vibrant colors, expressive eyes, detailed cel shading, 2D animation look"
negative_prompt = "photorealistic, 3d render, realistic, noisy, blurry"

prompt = "anime TV series style, 2D cel animation, hand-drawn look, traditional Japanese animation, anime screenshot, animation frame, flat shading, clean lineart, limited shading, soft gradients, vibrant anime colors, expressive anime eyes, studio quality anime, key visual from anime episode"
negative_prompt = "photorealistic, realism, 3d, 3d render, CGI, unreal engine, pixar, disney, semi-realistic, hyperrealistic, highly detailed skin, pores, noise, blurry"

## 애니메이션 ㄹㅇ
prompt = "anime illustration style, soft pastel color palette, gentle lighting,2D anime artwork, clean lineart, soft cel shading,light colors, low contrast, airy atmosphere,expressive anime eyes, cute and calm mood,high-quality anime illustration"
negative_prompt = "photorealistic, realism, 3d, 3d render, CGI, unreal engine,harsh lighting, strong shadows, high contrast,dark colors, gritty, noisy, blurry,hyperrealistic, highly detailed skin, pores"

prompt = "anime style, soft pastel color palette, gentle lighting, 2D anime artwork, simple clean lineart, subtle cel shading, light colors, low contrast, soft and airy atmosphere, natural anime eyes, cute and calm mood, simple anime aesthetic"
negative_prompt = "photorealistic, realism, 3d, 3d render, CGI, unreal engine, illustration, painterly, concept art, key visual, harsh lighting, strong shadows, high contrast, dark colors, gritty, noisy, blurry, hyperrealistic, highly detailed skin, pores"


prompt = "anime TV series style, soft pastel color palette, gentle lighting, 2D cel animation, anime screenshot, animation frame, simple clean lineart, flat and subtle cel shading, light colors, low contrast, soft and airy atmosphere, natural anime eyes, calm and cute mood, broadcast anime aesthetic"

negative_prompt = "photorealistic, realism, 3d, 3d render, CGI, unreal engine, illustration, painterly, concept art, key visual, highly detailed, harsh lighting, strong shadows, high contrast, dark colors, gritty, noisy, blurry, hyperrealistic, highly detailed skin, pores"


prompt = "TV anime series style, Japanese 2D cel animation, anime broadcast frame, raw animation cel look, hand-drawn animation frame, limited animation style, simple flat colors, very subtle cel shading, pastel color palette, low saturation, low contrast, soft and gentle lighting, minimal details, natural anime eyes, calm everyday anime mood"

negative_prompt = "illustration, key visual, concept art, painterly, photorealistic, realism, 3d, 3d render, CGI, unreal engine, cinematic lighting, dramatic lighting, harsh shadows, high contrast, dark colors, ultra detailed, highly detailed skin, pores, noise, blur"


prompt = "bright TV anime series style, Japanese 2D cel animation, anime broadcast screenshot, hand-drawn animation frame, limited animation style, in-between frame look, very simple lineart, flat pastel colors, high-key lighting, bright and airy atmosphere, low contrast, minimal shading, clean anime color design, natural anime eyes, cheerful and calm everyday anime mood"

negative_prompt = "illustration, key visual, concept art, painterly, photorealistic, realism, 3d, 3d render, CGI, unreal engine, cinematic lighting, dramatic lighting, harsh shadows, high contrast, dark mood, dark colors, ultra detailed, highly detailed skin, pores, noise, blur"


prompt = "anime illustration style, soft pastel color palette, gentle lighting,2D anime artwork, clean lineart, soft cel shading,light colors, low contrast, airy atmosphere,expressive anime eyes, cute and calm mood,high-quality anime illustration"
negative_prompt = "photorealistic, realism, 3d, 3d render, CGI, unreal engine,harsh lighting, strong shadows, high contrast,dark colors, gritty, noisy, blurry,hyperrealistic, highly detailed skin, pores"


prompt = "masterpiece, best quality, ultra-detailed, cinematic lighting, (cloverworks style:1.2), kaoru hana wa rin to saku, 1boy 1girl, male lead with sharp eyes and black hair, gentle expression, female lead with long wavy light brown hair and bright smile, school uniform, indoor cake shop background, soft warm sunlight filtering through windows, flower petals fluttering, pastel colors, emotional atmosphere, highres, anime style, vivid colors"

negative_prompt = "lowres, bad anatomy, bad hands, text, error, missing fingers, extra digit, fewer digits, cropped, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, blurry, artist name, realistic, 3d, monochrome, sketch"
prompt = "masterpiece, best quality, (cloverworks style:1.3), (kaoru hana wa rin to saku style:1.2), official art, high-definition anime, clean lines, detailed eyes, expressive face, soft shading, vibrant but warm colors, cinematic lighting, (atmospheric:1.1), (scenic:1.1), highres, aesthetic"

negative_prompt = "lowres, bad anatomy, bad hands, text, error, missing fingers, extra digit, fewer digits, cropped, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, blurry, artist name, realistic, 3d, monochrome, sketch, cherry blossoms, flower petals, falling petals"

prompt = "masterpiece, best quality, (cloverworks style:1.3), (kaoru hana wa rin to saku style:1.2), flat color, simple shading, anime style, 1boy 1girl, high school student, male lead with sharp eyes and neat black hair, female lead with long wavy light brown hair and soft smile, detailed school uniform, warm atmosphere, patisserie background, indoor, soft natural lighting, highres, clean lineart, aesthetic, vivid colors"

negative_prompt = "lowres, bad anatomy, bad hands, text, error, missing fingers, extra digit, fewer digits, cropped, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, blurry, artist name, realistic, 3d, monochrome, sketch, (shadow:1.3), heavy shadow, dark, cherry blossoms, flower petals, falling petals"

# prompt ="anime style illustration, original character, a noble and elegant character standing among blooming fragrant flowers, strong and dignified pose, calm but confident expression,soft wind flowing through hair and clothes,cinematic lighting, pastel yet vivid color palette,high detail anime artwork, clean lineart, smooth shading,beautiful background with flowers in full bloom,symbolic atmosphere of strength and elegance,Japanese animation key visual style, studio qualit"
# negative_prompt = "low quality, low resolution, blurry, pixelated,bad anatomy, extra limbs, missing fingers, deformed face,ugly, grotesque, horror, dark gritty style,photorealistic, realistic skin texture,3d render, western cartoon style,overexposed, underexposed, noisy background,text, watermark, logo"

prompt = "Please render in Samurai Champloo anime style of fusion of Edo-period Japanese aesthetics, layered backgrounds, light brushtroke patterns, almost lofi"
negative_prompt = "shadow, shading, lighting, highlight, rim light,3D, depth, perspective exaggeration,realistic lighting, volumetric light,photorealistic, detailed skin texture,painterly style, oil painting, watercolor,gradient heavy shading, dramatic contrast,low quality, blurry, noisy,bad anatomy, extra limbs, deformed face,text, watermark, logo"

prompt = "Genshin Impact style, detailed fantasy landscape, vibrant colors, anime character, dynamic pose, magical atmosphere, high quality, cinematic lighting, intricate costume design"

negative_prompt = "blurry, low quality, bad anatomy, deformed, extra limbs, blurry background, text, watermark"
prompt = "Genshin Impact style, 2D anime illustration, flat colors, cel shading, detailed fantasy background, cute anime character, dynamic pose, magical atmosphere, high quality, vibrant colors, cinematic lighting"

prompt = "Realistic Art, anime style"
negative_prompt = "blurry, low quality, bad anatomy, deformed, extra limbs, blurry background, text, watermark, realistic, 3D, photorealistic"


prompt = "Spy x Family style, 2D anime illustration, flat colors, cel shading, expressive cute characters, dynamic pose, cozy indoor or city background, high quality, vibrant colors, warm lighting, detailed eyes and hair, soft shadows"

negative_prompt = "blurry, low quality, bad anatomy, deformed, extra limbs, blurry background, text, watermark, realistic, 3D, photorealistic"

prompt = "Spy x Family style, 2D anime illustration, flat colors, cel shading, matte finish, no gloss or shine, expressive cute characters, dynamic pose, cozy indoor or city background, high quality, vibrant colors, warm lighting, detailed eyes and hair, soft shadows"

negative_prompt = "blurry, low quality, bad anatomy, deformed, extra limbs, blurry background, text, watermark, realistic, 3D, photorealistic, shiny, glossy, metallic, reflective"

prompt = "Spy x Family style, 2D anime illustration, flat colors, cel shading, completely matte, no gloss, no shine, no reflections, minimal blush, natural facial expression, eyes open, expressive cute characters, dynamic pose, cozy indoor or city background, simple textures, high quality, warm lighting, soft shadows, cartoon style"

negative_prompt = "blurry, low quality, bad anatomy, deformed, extra limbs, blurry background, text, watermark, realistic, 3D, photorealistic, shiny, glossy, metallic, reflective, specular highlights, polished, oil painting, exaggerated blush, closed eyes"


prompt = "Spy x Family style, 2D anime illustration, flat colors, cel shading, completely matte, no gloss, no shine, no reflections, no blush, natural facial expression, eyes open, expressive cute characters, dynamic pose, cozy indoor or city background, simple textures, high quality, warm lighting, soft shadows, cartoon style"

negative_prompt = "볼터치, blurry, low quality, bad anatomy, deformed, extra limbs, blurry background, text, watermark, realistic, 3D, photorealistic, shiny, glossy, metallic, reflective, specular highlights, polished, oil painting, blush, closed eyes, makeup, rouge, cheek tint"


prompt = "Spy x Family style, 2D anime illustration, flat colors, cel shading, completely matte, no gloss, no shine, no reflections, natural facial expression, eyes open, no blush, no cheek color, no rouge, no makeup, simple textures, cozy indoor or city background, high quality, warm lighting, soft shadows, cartoon style"

negative_prompt = "blurry, low quality, bad anatomy, deformed, extra limbs, blurry background, text, watermark, realistic, 3D, photorealistic, shiny, glossy, metallic, reflective, specular highlights, polished, oil painting, blush, cheek, cheek tint, rouge, makeup, cosmetic, pink cheeks, closed eyes, exaggerated facial colors"


prompt = "Spy x Family style, 2D anime illustration, flat colors, cel shading, completely matte, no gloss, no shine, no reflections, natural facial expression, eyes open, neutral skin tone, pale skin, no blush, no cheek color, no rouge, no pink, simple textures, cozy indoor or city background, high quality, warm lighting, soft shadows, cartoon style"

negative_prompt = "blurry, low quality, bad anatomy, deformed, extra limbs, blurry background, text, watermark, realistic, 3D, photorealistic, shiny, glossy, metallic, reflective, specular highlights, polished, oil painting, blush, cheek, cheek tint, rouge, makeup, pink cheeks, red cheeks, warm skin, reddish skin, closed eyes, exaggerated facial colors"

prompt = "anime style, masterpiece, best quality, 2d, highres, flat color, original eyes,close eyes, open eyes"
negative_prompt = "photorealistic, real life, 3d, realistic, blurry, lowres, bad anatomy"



# prompt = (
#     "Convert to Spy x Family style, 2D anime illustration, flat colors, cel shading, "
#     "completely matte, no gloss, no shine, no reflections, uniform skin color, "
#     "no blush, no cheek color, no rouge, simple skin texture, smooth skin, "
#     "cartoon-style skin, high quality, soft lighting, no shadows"
# )

# negative_prompt = (
#     "blurry, low quality, bad anatomy, deformed, extra limbs, shiny, glossy, "
#     "metallic, reflective, specular highlights, polished, oil painting, blush, "
#     "cheek, cheek tint, rouge, makeup, pink cheeks, red cheeks, shadows, shading, "
#     "gradient, lighting variation, specular"
# )

# 4. 이미지 생성 (Img2Img)
image = pipe(
    prompt=prompt,
    negative_prompt=negative_prompt,
    image=init_image,          # 원본 이미지 입력
    strength=0.4,              # 중요: 0.0일수록 원본 유지, 1.0일수록 프롬프트에 충실 (0.5~0.7 추천) 0.6 11
    num_inference_steps=11,
    guidance_scale=0.0,
    generator=torch.Generator("cuda").manual_seed(42),
).images[0]

# 5. 저장
image.save("anime_result.png")
print("애니메이션 스타일 변환 완료 및 저장!")

# %% [markdown]
# ### 2스텝 픽셀화

# %%
import torch
from diffusers import ZImageImg2ImgPipeline # Img2Img 전용 파이프라인으로 변경
from diffusers.utils import load_image

# 1. 파이프라인 로드 (Img2Img용)
pipe = ZImageImg2ImgPipeline.from_pretrained(
    "Tongyi-MAI/Z-Image-Turbo",
    torch_dtype=torch.bfloat16,
    low_cpu_mem_usage=True,
)
pipe.to("cuda")

# 2. 원본 이미지 불러오기 (경로를 본인의 파일명으로 수정하세요)
init_image = load_image("21.png").convert("RGB")

# 3. 애니메이션 스타일 프롬프트 설정
prompt = "anime style, high-quality, vibrant colors, expressive eyes, detailed cel shading, 2D animation look"
negative_prompt = "photorealistic, 3d render, realistic, noisy, blurry"

prompt = "anime TV series style, 2D cel animation, hand-drawn look, traditional Japanese animation, anime screenshot, animation frame, flat shading, clean lineart, limited shading, soft gradients, vibrant anime colors, expressive anime eyes, studio quality anime, key visual from anime episode"
negative_prompt = "photorealistic, realism, 3d, 3d render, CGI, unreal engine, pixar, disney, semi-realistic, hyperrealistic, highly detailed skin, pores, noise, blurry"

## 애니메이션 ㄹㅇ
prompt = "anime illustration style, soft pastel color palette, gentle lighting,2D anime artwork, clean lineart, soft cel shading,light colors, low contrast, airy atmosphere,expressive anime eyes, cute and calm mood,high-quality anime illustration"
negative_prompt = "photorealistic, realism, 3d, 3d render, CGI, unreal engine,harsh lighting, strong shadows, high contrast,dark colors, gritty, noisy, blurry,hyperrealistic, highly detailed skin, pores"

prompt = "anime style, soft pastel color palette, gentle lighting, 2D anime artwork, simple clean lineart, subtle cel shading, light colors, low contrast, soft and airy atmosphere, natural anime eyes, cute and calm mood, simple anime aesthetic"
negative_prompt = "photorealistic, realism, 3d, 3d render, CGI, unreal engine, illustration, painterly, concept art, key visual, harsh lighting, strong shadows, high contrast, dark colors, gritty, noisy, blurry, hyperrealistic, highly detailed skin, pores"


prompt = "anime TV series style, soft pastel color palette, gentle lighting, 2D cel animation, anime screenshot, animation frame, simple clean lineart, flat and subtle cel shading, light colors, low contrast, soft and airy atmosphere, natural anime eyes, calm and cute mood, broadcast anime aesthetic"

negative_prompt = "photorealistic, realism, 3d, 3d render, CGI, unreal engine, illustration, painterly, concept art, key visual, highly detailed, harsh lighting, strong shadows, high contrast, dark colors, gritty, noisy, blurry, hyperrealistic, highly detailed skin, pores"


prompt = "TV anime series style, Japanese 2D cel animation, anime broadcast frame, raw animation cel look, hand-drawn animation frame, limited animation style, simple flat colors, very subtle cel shading, pastel color palette, low saturation, low contrast, soft and gentle lighting, minimal details, natural anime eyes, calm everyday anime mood"

negative_prompt = "illustration, key visual, concept art, painterly, photorealistic, realism, 3d, 3d render, CGI, unreal engine, cinematic lighting, dramatic lighting, harsh shadows, high contrast, dark colors, ultra detailed, highly detailed skin, pores, noise, blur"


prompt = "bright TV anime series style, Japanese 2D cel animation, anime broadcast screenshot, hand-drawn animation frame, limited animation style, in-between frame look, very simple lineart, flat pastel colors, high-key lighting, bright and airy atmosphere, low contrast, minimal shading, clean anime color design, natural anime eyes, cheerful and calm everyday anime mood"

negative_prompt = "illustration, key visual, concept art, painterly, photorealistic, realism, 3d, 3d render, CGI, unreal engine, cinematic lighting, dramatic lighting, harsh shadows, high contrast, dark mood, dark colors, ultra detailed, highly detailed skin, pores, noise, blur"


prompt = "anime illustration style, soft pastel color palette, gentle lighting,2D anime artwork, clean lineart, soft cel shading,light colors, low contrast, airy atmosphere,expressive anime eyes, cute and calm mood,high-quality anime illustration"
negative_prompt = "photorealistic, realism, 3d, 3d render, CGI, unreal engine,harsh lighting, strong shadows, high contrast,dark colors, gritty, noisy, blurry,hyperrealistic, highly detailed skin, pores"


prompt = "masterpiece, best quality, ultra-detailed, cinematic lighting, (cloverworks style:1.2), kaoru hana wa rin to saku, 1boy 1girl, male lead with sharp eyes and black hair, gentle expression, female lead with long wavy light brown hair and bright smile, school uniform, indoor cake shop background, soft warm sunlight filtering through windows, flower petals fluttering, pastel colors, emotional atmosphere, highres, anime style, vivid colors"

negative_prompt = "lowres, bad anatomy, bad hands, text, error, missing fingers, extra digit, fewer digits, cropped, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, blurry, artist name, realistic, 3d, monochrome, sketch"
prompt = "masterpiece, best quality, (cloverworks style:1.3), (kaoru hana wa rin to saku style:1.2), official art, high-definition anime, clean lines, detailed eyes, expressive face, soft shading, vibrant but warm colors, cinematic lighting, (atmospheric:1.1), (scenic:1.1), highres, aesthetic"

negative_prompt = "lowres, bad anatomy, bad hands, text, error, missing fingers, extra digit, fewer digits, cropped, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, blurry, artist name, realistic, 3d, monochrome, sketch, cherry blossoms, flower petals, falling petals"

prompt = "masterpiece, best quality, (cloverworks style:1.3), (kaoru hana wa rin to saku style:1.2), flat color, simple shading, anime style, 1boy 1girl, high school student, male lead with sharp eyes and neat black hair, female lead with long wavy light brown hair and soft smile, detailed school uniform, warm atmosphere, patisserie background, indoor, soft natural lighting, highres, clean lineart, aesthetic, vivid colors"

negative_prompt = "lowres, bad anatomy, bad hands, text, error, missing fingers, extra digit, fewer digits, cropped, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, blurry, artist name, realistic, 3d, monochrome, sketch, (shadow:1.3), heavy shadow, dark, cherry blossoms, flower petals, falling petals"

# prompt ="anime style illustration, original character, a noble and elegant character standing among blooming fragrant flowers, strong and dignified pose, calm but confident expression,soft wind flowing through hair and clothes,cinematic lighting, pastel yet vivid color palette,high detail anime artwork, clean lineart, smooth shading,beautiful background with flowers in full bloom,symbolic atmosphere of strength and elegance,Japanese animation key visual style, studio qualit"
# negative_prompt = "low quality, low resolution, blurry, pixelated,bad anatomy, extra limbs, missing fingers, deformed face,ugly, grotesque, horror, dark gritty style,photorealistic, realistic skin texture,3d render, western cartoon style,overexposed, underexposed, noisy background,text, watermark, logo"

prompt = "Please render in Samurai Champloo anime style of fusion of Edo-period Japanese aesthetics, layered backgrounds, light brushtroke patterns, almost lofi"
negative_prompt = "shadow, shading, lighting, highlight, rim light,3D, depth, perspective exaggeration,realistic lighting, volumetric light,photorealistic, detailed skin texture,painterly style, oil painting, watercolor,gradient heavy shading, dramatic contrast,low quality, blurry, noisy,bad anatomy, extra limbs, deformed face,text, watermark, logo"

prompt = "Genshin Impact style, detailed fantasy landscape, vibrant colors, anime character, dynamic pose, magical atmosphere, high quality, cinematic lighting, intricate costume design"

negative_prompt = "blurry, low quality, bad anatomy, deformed, extra limbs, blurry background, text, watermark"
prompt = "Genshin Impact style, 2D anime illustration, flat colors, cel shading, detailed fantasy background, cute anime character, dynamic pose, magical atmosphere, high quality, vibrant colors, cinematic lighting"

prompt = "Realistic Art, anime style"
negative_prompt = "blurry, low quality, bad anatomy, deformed, extra limbs, blurry background, text, watermark, realistic, 3D, photorealistic"


prompt = "Spy x Family style, 2D anime illustration, flat colors, cel shading, expressive cute characters, dynamic pose, cozy indoor or city background, high quality, vibrant colors, warm lighting, detailed eyes and hair, soft shadows"

negative_prompt = "blurry, low quality, bad anatomy, deformed, extra limbs, blurry background, text, watermark, realistic, 3D, photorealistic"

prompt = "Spy x Family style, 2D anime illustration, flat colors, cel shading, matte finish, no gloss or shine, expressive cute characters, dynamic pose, cozy indoor or city background, high quality, vibrant colors, warm lighting, detailed eyes and hair, soft shadows"

negative_prompt = "blurry, low quality, bad anatomy, deformed, extra limbs, blurry background, text, watermark, realistic, 3D, photorealistic, shiny, glossy, metallic, reflective"

prompt = "Spy x Family style, 2D anime illustration, flat colors, cel shading, completely matte, no gloss, no shine, no reflections, minimal blush, natural facial expression, eyes open, expressive cute characters, dynamic pose, cozy indoor or city background, simple textures, high quality, warm lighting, soft shadows, cartoon style"

negative_prompt = "blurry, low quality, bad anatomy, deformed, extra limbs, blurry background, text, watermark, realistic, 3D, photorealistic, shiny, glossy, metallic, reflective, specular highlights, polished, oil painting, exaggerated blush, closed eyes"


prompt = "Spy x Family style, 2D anime illustration, flat colors, cel shading, completely matte, no gloss, no shine, no reflections, no blush, natural facial expression, eyes open, expressive cute characters, dynamic pose, cozy indoor or city background, simple textures, high quality, warm lighting, soft shadows, cartoon style"

negative_prompt = "blurry, low quality, bad anatomy, deformed, extra limbs, blurry background, text, watermark, realistic, 3D, photorealistic, shiny, glossy, metallic, reflective, specular highlights, polished, oil painting, blush, cheek, cheek tint, rouge, makeup, pink cheeks, red cheeks, exaggerated facial colors, shadows"
prompt = "Spy x Family style, 2D anime illustration, flat colors, cel shading, completely matte, no gloss, no shine, no reflections, uniform skin color, no blush, no cheek color, no rouge, simple textures, cozy indoor or city background, high quality, soft lighting, cartoon style, no shadows, no shading, flat lighting"

negative_prompt = "blurry, low quality, bad anatomy, deformed, extra limbs, blurry background, text, watermark, realistic, 3D, photorealistic, shiny, glossy, metallic, reflective, specular highlights, polished, oil painting, blush, cheek, cheek tint, rouge, makeup, pink cheeks, red cheeks, shadows, shading, gradient, lighting variation, specular"
prompt = "Convert to Spy x Family style, 2D anime illustration, flat colors, cel shading, completely matte, no gloss, no shine, no reflections, uniform skin color, no blush, no cheek color, no rouge, simple textures, high quality, soft lighting, cartoon style, no shadows, no shading, flat lighting"

negative_prompt = "blurry, low quality, bad anatomy, deformed, extra limbs, shiny, glossy, metallic, reflective, specular highlights, polished, oil painting, blush, cheek, cheek tint, rouge, makeup, pink cheeks, red cheeks, shadows, shading, gradient, lighting variation, specular"


prompt = "anime style, masterpiece, best quality, 2d, highres, flat color, original eyes,close eyes, open eyes"
negative_prompt = "photorealistic, real life, 3d, realistic, blurry, lowres, bad anatomy"



# prompt = (
#     "Convert to Spy x Family style, 2D anime illustration, flat colors, cel shading, "
#     "completely matte, no gloss, no shine, no reflections, uniform skin color, "
#     "no blush, no cheek color, no rouge, simple skin texture, smooth skin, "
#     "cartoon-style skin, high quality, soft lighting, no shadows"
# )

# negative_prompt = (
#     "blurry, low quality, bad anatomy, deformed, extra limbs, shiny, glossy, "
#     "metallic, reflective, specular highlights, polished, oil painting, blush, "
#     "cheek, cheek tint, rouge, makeup, pink cheeks, red cheeks, shadows, shading, "
#     "gradient, lighting variation, specular"
# )

# 4. 이미지 생성 (Img2Img)
image = pipe(
    prompt=prompt,
    negative_prompt=negative_prompt,
    image=init_image,          # 원본 이미지 입력
    strength=0.4,              # 중요: 0.0일수록 원본 유지, 1.0일수록 프롬프트에 충실 (0.5~0.7 추천) 0.6 11
    num_inference_steps=11,
    guidance_scale=0.0,
    generator=torch.Generator("cuda").manual_seed(42),
).images[0]

# 5. 저장
image.save("anime_result.png")
print("애니메이션 스타일 변환 완료 및 저장!")

# %%
import torch
import gc
import math
from PIL import Image
from diffusers import ZImageImg2ImgPipeline, utils

def run_img2img():
    # 1. 파이프라인 로드
    model_id = "Tongyi-MAI/Z-Image-Turbo"
    print("모델 로딩 중...")
    pipe = ZImageImg2ImgPipeline.from_pretrained(
        model_id,
        torch_dtype=torch.bfloat16,
        low_cpu_mem_usage=True,
    )
    pipe.to("cuda")

    # 2. LoRA 스타일 적용
    print("LoRA 가중치 로드 중...")
    pipe.load_lora_weights("reverentelusarca/elusarca-pixel-art-style-lora-zimage-turbo")
    #pipe.load_lora_weights("reverentelusarca/elusarca-anime-style-lora-z-image-turbo")

    # 3. 원본 이미지 준비 및 해상도 보정
    try:
        #init_image = Image.open("anime_result.png").convert("RGB")
        init_image = Image.open("anime_result.png").convert("RGB")
        orig_width, orig_height = init_image.size
        print(f"원본 해상도: {orig_width}x{orig_height}")

        # 16의 배수로 맞추기 (ValueError 해결)
        new_width = math.ceil(orig_width / 16) * 16
        new_height = math.ceil(orig_height / 16) * 16
        
        if orig_width != new_width or orig_height != new_height:
            print(f"해상도 보정: {orig_width}x{orig_height} -> {new_width}x{new_height}")
            input_image = init_image.resize((new_width, new_height), Image.LANCZOS)
        else:
            input_image = init_image

    except Exception as e:
        print(f"이미지 로드 실패: {e}")
        return

    # 4. 이미지 생성
    print("이미지 생성 시작...")
    # prompt = "pixel art, pastel color, very light"
   # prompt = "pixel art, preserve original colors,preserve original lighting, preserve original image details. 2D anime"
   # prompt = "Convert to genshin, 2D anime illustration,cel shading,  high quality, soft pixel art"

    # 애니풍 2D 이미지 생성용 프롬프트 변수
    #prompt ="2D anime-style illustration, cel shading, high quality, pixel art, vibrant colors, dynamic anime pose, expressive eyes, clean line art, dramatic lighting, cinematic composition,preserve original colors, preserve original lighting, preserve original image details,preserve original clothes"
    #prompt = "pixel art"
    prompt = "pixel art, Convert to Spy x Family style, 2D anime illustration, flat colors, cel shading, completely matte, no gloss, no shine, no reflections, uniform skin color, no blush, no cheek color, no rouge, simple textures, high quality, soft lighting, cartoon style, no shadows, no shading, flat lighting"
    #prompt = "pixel art,anime style, masterpiece, best quality, 2d, highres, flat color, Convert to Spy x Family style, 2D anime illustration, flat colors, cel shading, completely matte, no gloss, no shine, no reflections, uniform skin color, no blush, no cheek color, no rouge, simple textures, high quality, soft lighting, cartoon style, no shadows, no shading, flat lighting"
    prompt = "pixel art, 2D anime illustration,very flat colors, cel shading, matte,anime style, masterpiece, best quality, 2d, highres, flat color"
    
    image = pipe(
        prompt=prompt,
        image=input_image,
        strength=0.499,                 #0.46 0.46 3   0.35 3
        num_inference_steps=6,#0.38 6
        guidance_scale=0.0,
        height=new_height, # 보정된 높이
        width=new_width,   # 보정된 너비
        generator=torch.Generator("cuda").manual_seed(42),
    ).images[0]

    # 수정 제안 파라미터
    # image = pipe(
    #     prompt=prompt,
    #     image=input_image,
    #     # 1. 단계를 조금 늘려 strength가 먹힐 공간을 확보합니다.
    #     num_inference_steps=10, 
    #     # 2. 10 * 0.4 = 4단계 정도 실행되므로 LoRA 스타일이 반영될 시간이 생깁니다.
    #     strength=0.4,           
    #     # 3. Turbo 모델이라도 약간의 가이던스를 주면 프롬프트가 더 잘 먹힙니다.
    #     guidance_scale=4.0,     
    #     height=new_height,
    #     width=new_width,
    #     generator=torch.Generator("cuda").manual_seed(42),
    # ).images[0]

    # 5. 최종 결과물을 다시 원본 해상도(예: 761)로 복원
    if image.size != (orig_width, orig_height):
        image = image.resize((orig_width, orig_height), Image.LANCZOS)

    # 6. 저장
    image.save("pixel_art_output3.png")
    print(f"저장 완료: pixel_art_output.png ({orig_width}x{orig_height})")

    # 7. 메모리 비우기
    
    print("메모리 정리 중...")
    del pipe
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
        torch.cuda.ipc_collect()
    print("모든 작업이 완료되었습니다.")

if __name__ == "__main__":
    run_img2img()
